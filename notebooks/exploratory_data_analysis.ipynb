# %% [markdown]
# ### Exploratory data analysis (EDA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('/Users/tarakram/Documents/Recommendation-Project/data/processed/pre-processed_data.csv')

# %%
books.head()
# Out:
#    Unnamed: 0  user_id        ISBN  rating  \
# 0           0   277427  002542730X      10
# 1           1     3363  002542730X       0
# 2           2    11676  002542730X       6
# 3           3    12538  002542730X      10
# 4           4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc
#
#                                            image_url  num_of_rating
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/002542730X.0...             82
# 2  http://images.amazon.com/images/P/002542730X.0...             82
# 3  http://images.amazon.com/images/P/002542730X.0...             82
# 4  http://images.amazon.com/images/P/002542730X.0...             82

# %%
books.shape
# Out:
# (59850, 9)

# %%
books.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
Book_Rating = books['rating']
Book_Title = books['title']
Publisher = books['publisher']
year = books['year']

# %%
# The Distribution of Age and Book Rating
plt.hist(x=year, weights=Book_Rating, align='mid')
plt.title('year vs Book Rating')
plt.xlabel('year')
plt.ylabel('Book Rating')
# Out:
# Text(0, 0.5, 'Book Rating')

# %%
# I want to find top 5 publisher has higest rating.
avg_ratings = books.groupby('publisher')['rating'].mean().sort_values(ascending = False)[:10]
print("These are the top 10 publishers with the highest average rating:")
for i, publisher in enumerate(avg_ratings.index, start=1):
    print(f'{i}. {publisher}: {avg_ratings[publisher]:.2f}')
# Out:
# These are the top 10 publishers with the highest average rating:
# 1. Landoll: 10.00
# 2. Houghton Mifflin Co: 10.00
# 3. Five Star (ME): 10.00
# 4. BBC Consumer Publishing: 10.00
# 5. Golden Books: 10.00
# 6. Scholastic Library Pub: 10.00
# 7. Titan Books: 10.00
# 8. Cambridge University Press: 10.00
# 9. Lothian Pub Co: 10.00
# 10. Ariel Press: 10.00

# %%
# Create a horizontal bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x=avg_ratings.values, y=avg_ratings.index, palette='viridis')

plt.xlabel("Average Rating")
plt.ylabel("Publisher")
plt.title("Top 10 Publishers with Highest Average Rating")

plt.show()

# %%
# I want to find the top 5 rating books.
book_ratings = books.groupby('title')['rating'].mean().sort_values(ascending=False)[:10]

# Print the top books with their average rating
print("These are the top 10 books with the highest average rating:")
for i, book_title in enumerate(book_ratings.index, start=1):
    print(f'{i}. {book_title}: {book_ratings[book_title]:.2f}')
# Out:
# These are the top 10 books with the highest average rating:
# 1. The Little Prince: 5.12
# 2. Harry Potter and the Sorcerer's Stone (Book 1): 4.72
# 3. Harry Potter and the Prisoner of Azkaban (Book 3): 4.59
# 4. 84 Charing Cross Road: 4.57
# 5. Harry Potter and the Goblet of Fire (Book 4): 4.44
# 6. Harry Potter and the Order of the Phoenix (Book 5): 4.18
# 7. A Wrinkle in Time: 4.00
# 8. The Secret Garden: 3.94
# 9. Harry Potter and the Chamber of Secrets (Book 2): 3.85
# 10. Carrie: 3.81

# %%
# Create a horizontal bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x=book_ratings.values, y=book_ratings.index, palette='viridis')

plt.xlabel("Book Rating")
plt.ylabel("Books")
plt.title("Top 10 Publishers with Highest Average Rating")

plt.show()

# %%
# I want to fing the top 5 authors having highest rating.
Author_ratings = books.groupby('author')['rating'].mean().sort_values(ascending=False)[:10]

# Print the top books with their average rating
print("These are the top 10 Authors with the highest average rating:")
for i, book_Author in enumerate(Author_ratings.index, start=1):
    print(f'{i}. {book_Author}: {Author_ratings[book_Author]:.2f}')
# Out:
# These are the top 10 Authors with the highest average rating:
# 1. Arthur Conan Doyle: 10.00
# 2. Golden Books: 10.00
# 3. Walter Simonson: 10.00
# 4. Jen McVeity: 10.00
# 5. Bradbury: 10.00
# 6. Marion Zimmer Bradley: 10.00
# 7. Sharon K. Garner: 10.00
# 8. Joan Grant: 10.00
# 9. Jerome David Salinger: 10.00
# 10. Joe Coomer: 9.00

# %%
# Create a horizontal bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x=Author_ratings.values, y=Author_ratings.index, palette='viridis')

plt.xlabel("Author Rating")
plt.ylabel("Author Name")
plt.title("Top 10 Authors with Highest Average Rating")

plt.show()
