# %% [markdown]
# ### Exploratory data analysis (EDA)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('/Users/tarakram/Documents/Recommedation-System/data/processed/cleaned_data.csv')

# %%
books.head()
# Out:
#    Unnamed: 0        ISBN           Book-Title           Book-Author  \
# 0           0  0195153448  Classical Mythology    Mark P. O. Morford
# 1           1  0002005018         Clara Callan  Richard Bruce Wright
# 2           2  0002005018         Clara Callan  Richard Bruce Wright
# 3           3  0002005018         Clara Callan  Richard Bruce Wright
# 4           4  0002005018         Clara Callan  Richard Bruce Wright
#
#    Year-Of-Publication                Publisher  User-ID   Age  Book-Rating
# 0                 2002  Oxford University Press        2  18.0            0
# 1                 2001    HarperFlamingo Canada    11400  49.0            0
# 2                 2001    HarperFlamingo Canada    67544  30.0            8
# 3                 2001    HarperFlamingo Canada    85526  36.0            0
# 4                 2001    HarperFlamingo Canada    96054  29.0            0

# %%
Age = books['Age']
Book_Rating = books['Book-Rating']
Book_Title = books['Book-Title']
Publisher = books['Publisher']

# %%
# The Distribution of Age and Book Rating
plt.hist(x=Age, weights=Book_Rating, bins=30, align='mid')
plt.title('Age vs Book Rating')
plt.xlabel('Age')
plt.ylabel('Book Rating')
# Out:
# Text(0, 0.5, 'Book Rating')

# %%
# I want to find top 5 publisher has higest rating.
avg_ratings = books.groupby('Publisher')['Book-Rating'].mean().sort_values(ascending = False)[:10]
print("These are the top 10 publishers with the highest average rating:")
for i, publisher in enumerate(avg_ratings.index, start=1):
    print(f'{i}. {publisher}: {avg_ratings[publisher]:.2f}')
# Out:
# These are the top 10 publishers with the highest average rating:
# 1.  Editions P. Terrail: 10.00
# 2. Unicorn Pub. House: 10.00
# 3. Ulmer (Eugen): 10.00
# 4. Ediciones Zarebska: 10.00
# 5. Ediciones Torremozas: 10.00
# 6. Ediciones SÃ­gueme: 10.00
# 7. Ediciones Libro-Reportaje: 10.00
# 8. Ediciones Fraile: 10.00
# 9. Umbrella Press: 10.00
# 10. Umi Research Pr: 10.00

# %%
# Create a horizontal bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x=avg_ratings.values, y=avg_ratings.index, palette='viridis')

plt.xlabel("Average Rating")
plt.ylabel("Publisher")
plt.title("Top 10 Publishers with Highest Average Rating")

plt.show()

# %%
# I want to find the top 5 rating books.
book_ratings = books.groupby('Book-Title')['Book-Rating'].mean().sort_values(ascending=False)[:10]

# Print the top books with their average rating
print("These are the top 10 books with the highest average rating:")
for i, book_title in enumerate(book_ratings.index, start=1):
    print(f'{i}. {book_title}: {book_ratings[book_title]:.2f}')
# Out:
# These are the top 10 books with the highest average rating:
# 1. The Mountains of California (Modern Library Classics): 10.00
# 2. Keane: 10.00
# 3. Marconi's Atlantic Leap: 10.00
# 4. One pot meals: 10.00
# 5. Baubles, Buttons and Beads: The Heritage of Bohemia: 10.00
# 6. The Music of Black Americans: A History: 10.00
# 7. Katzen kennen und verstehen. KÃ?Â¶rpersprache und Verhalten.: 10.00
# 8. Marco's Millions: 10.00
# 9. Today's Been a Helluva Week: 10.00
# 10. Katzen. Kennen lernen, Haltung, Pflege, ZÃ?Â¼chtung.: 10.00

# %%
# Create a horizontal bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x=book_ratings.values, y=book_ratings.index, palette='viridis')

plt.xlabel("Book Rating")
plt.ylabel("Books")
plt.title("Top 10 Publishers with Highest Average Rating")

plt.show()

# %%
# I want to fing the top 5 authors having highest rating.
Author_ratings = books.groupby('Book-Author')['Book-Rating'].mean().sort_values(ascending=False)[:10]

# Print the top books with their average rating
print("These are the top 10 Authors with the highest average rating:")
for i, book_Author in enumerate(Author_ratings.index, start=1):
    print(f'{i}. {book_Author}: {Author_ratings[book_Author]:.2f}')
# Out:
# These are the top 10 Authors with the highest average rating:
# 1. Duncan Campbell: 10.00
# 2. Various Authors: 10.00
# 3. Owen Guthrie: 10.00
# 4. Editor: 10.00
# 5. B. A. Bodkin: 10.00
# 6. Sahar  Hashemi: 10.00
# 7. Editors of Country Living: 10.00
# 8. Vanessa Gill-Brown: 10.00
# 9. Otto Sander: 10.00
# 10. Cat Summers: 10.00

# %%
# Create a horizontal bar plot using Seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x=Author_ratings.values, y=Author_ratings.index, palette='viridis')

plt.xlabel("Author Rating")
plt.ylabel("Author Name")
plt.title("Top 10 Authors with Highest Average Rating")

plt.show()
